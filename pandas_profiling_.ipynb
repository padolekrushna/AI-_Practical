# %% [markdown]
# <a href="https://colab.research.google.com/github/padolekrushna/AI-_Practical/blob/main/pandas_profiling_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install pandas profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.2/297.2 kB 7.5 MB/s eta 0:00:00
# ...
#   Created wheel for profiling: filename=profiling-0.1.3-cp310-cp310-linux_x86_64.whl size=45120 sha256=f8d1636f156e72fe5300575071cd6deb496826e78497899b9604412b9123cdb5
#   Stored in directory: /root/.cache/pip/wheels/80/4f/3c/567a19e92fec63d862feeac97c39c09e3a1a611b6e47468bcf
# ...
#   Created wheel for valuedispatch: filename=valuedispatch-0.0.1-py3-none-any.whl size=2020 sha256=c2d7e90da1e131cd41ef8110bd7df57561947bf061c40fcc2d894d37df7b29ec
#   Stored in directory: /root/.cache/pip/wheels/e4/86/b1/12043a94f1fcfb8376b4f37581ab8448c09658ba406abd5dc6
# Successfully built profiling valuedispatch
# ...

# %%
# !pip install ydata-profiling # Installs ydata-profiling, the new name for pandas-profiling
from ydata_profiling import ProfileReport # Imports ProfileReport from the correct module
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 78.4 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=ec07eac5e024c2649c3157ab98cb32dd6499d4eeadb9286a680e0e26cebef635
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
prof = ProfileReport(pd.read_excel('/content/RawData(1).xlsx'))
prof.to_file(output_file='Demo.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from google.colab import files
files.download('Demo.html')
